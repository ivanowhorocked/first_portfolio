# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
coasters = pd.read_csv('roller_coasters.csv')
coasters.sort_values(by = ['speed'], ascending = False).head(20)
# Out:
#                                 name material_type seating_type  speed  \
# 1397                   Formula Rossa         Steel     Sit Down  240.0
# 138                        Kingda Ka         Steel     Sit Down  206.0
# 143              Top Thrill Dragster         Steel     Sit Down  192.0
# 1751                       Red Force         Steel     Sit Down  185.0
# 140                       Do-Dodonpa         Steel     Sit Down  172.0
# 160   Superman : Escape from Krypton         Steel     Sit Down  160.0
# 1251                      Ring Racer         Steel     Sit Down  160.0
# 246               Tower of Terror II         Steel     Sit Down  160.0
# 603                Steel Dragon 2000         Steel     Sit Down  153.0
# 1829                        Fury 325         Steel     Sit Down  153.0
# 155                 Millennium Force         Steel     Sit Down  150.0
# 1628                       Leviathan         Steel     Sit Down  148.0
# 1407                 Intimidator 305         Steel     Sit Down  145.0
# 1805                        Hyperion         Steel     Sit Down  140.0
# 162                          Goliath         Steel     Sit Down  137.0
# 237                            Titan         Steel     Sit Down  137.0
# 2025              OCT Thrust SSC1000            na     Sit Down  137.0
# 2106      Coaster Through the Clouds            na     Sit Down  136.0
# 256                          Stealth         Steel     Sit Down  135.0
# 754                      Furius Baco         Steel         Wing  135.0
#
#       height  length  num_inversions manufacturer                       park  \
# 1397    52.0  2000.0             0.0      Intamin              Ferrari World
# 138    139.0   950.0             0.0      Intamin  Six Flags Great Adventure
# 143    128.0   853.0             0.0      Intamin                Cedar Point
# 1751   112.0   880.0             0.0      Intamin               Ferrari Land
# 140     52.0  1189.0             0.0          S&S            Fuji-Q Highland
# 160    126.0   376.0             0.0      Intamin   Six Flags Magic Mountain
# 1251    38.0  1215.0             0.0          S&S                Nürburgring
# 246    115.0   372.0             0.0      Intamin                 Dreamworld
# 603     97.0  2479.0             0.0       Morgan         Nagashima Spa Land
# 1829    99.0  2012.0             0.0          B&M                  Carowinds
# 155     94.0  2010.0             0.0      Intamin                Cedar Point
# 1628    93.0  1672.0             0.0          B&M        Canada's Wonderland
# 1407    93.0  1555.0             0.0      Intamin             Kings Dominion
# 1805    77.0  1450.0             1.0      Intamin               Energylandia
# 162     71.0  1370.0             0.0    Giovanola   Six Flags Magic Mountain
# 237     75.0  1619.0             0.0    Giovanola       Six flags Over Texas
# 2025    60.0     NaN             NaN          S&S         Happy Valley Wuhan
# 2106    74.0  1556.0             NaN      Intamin        Nanchang Wanda Park
# 256     63.0   400.0             0.0      Intamin                Thorpe Park
# 754     14.0   900.0             1.0      Intamin              Port Aventura
#
#                         status
# 1397          status.operating
# 138           status.operating
# 143           status.operating
# 1751          status.operating
# 140           status.operating
# 160           status.operating
# 1251  status.closed.definitely
# 246           status.operating
# 603           status.operating
# 1829          status.operating
# 155           status.operating
# 1628          status.operating
# 1407          status.operating
# 1805          status.operating
# 162           status.operating
# 237           status.operating
# 2025          status.operating
# 2106          status.operating
# 256           status.operating
# 754           status.operating

# %%
def column_hist(column, df):
    df2 = df.dropna()
    f, ax = plt.subplots(figsize = (12, 8 ))
    plt.hist(df2[column], bins = 20)
    plt.xlabel(column)
    plt.ylabel('count')
column_hist('speed', coasters)

# %%
def heights_hist(df):
    heights = df[df['height'] <= 140]
    plt.hist(heights['height'], bins=20)
    plt.xlabel('height')
    plt.ylabel('count')
    
heights_hist(coasters)
